# %%
import requests
import pandas as pd

# %%
import sys

# %%
print(sys.executable)
# Out:
# c:\projetos\football-data-pipeline\.venv\Scripts\python.exe

# %% [markdown]
# Teste da API

# %%
url = "https://api.football-data.org/v4/competitions"

response = requests.get(url)

response.status_code
# Out:
# 200

# %%
data = response.json()

type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['count', 'filters', 'competitions'])

# %%
data["competitions"][:3]
# Out:
# [{'id': 2176,
#   'area': {'id': 2001, 'name': 'Africa', 'code': 'AFR', 'flag': None},
#   'name': 'Africa Cup',
#   'code': 'AC',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/ac.png',
#   'plan': 'TIER_FOUR',
#   'currentSeason': {'id': 2385,
#    'startDate': '2025-12-21',
#    'endDate': '2026-01-18',
#    'currentMatchday': 3,
#    'winner': None},
#   'numberOfAvailableSeasons': 2,
#   'lastUpdated': '2024-01-13T11:34:43Z'},
#  {'id': 2166,
#   'area': {'id': 2001, 'name': 'Africa', 'code': 'AFR', 'flag': None},
#   'name': 'AFC Champions League',
#   'code': 'ACL',
#   'type': 'CUP',
#   'emblem': None,
#   'plan': 'TIER_FOUR',
#   'currentSeason': {'id': 1559,
#    'startDate': '2022-04-06',
#    'endDate': '2023-05-05',
#    'currentMatchday': None,
#    'winner': None},
#   'numberOfAvailableSeasons': 1,
#   'lastUpdated': '2023-02-26T12:57:33Z'},
#  {'id': 2006,
#   'area': {'id': 2001, 'name': 'Africa', 'code': 'AFR', 'flag': None},
#   'name': 'WC Qualification CAF',
#   'code': 'QCAF',
#   'type': 'CUP',
#   'emblem': None,
#   'plan': 'TIER_FOUR',
#   'currentSeason': {'id': 1609,
#    'startDate': '2023-11-15',
#    'endDate': '2025-10-13',
#    'currentMatchday': 10,
#    'winner': None},
#   'numberOfAvailableSeasons': 3,
#   'lastUpdated': '2022-03-13T18:51:44Z'}]

# %%
competitions_df = pd.DataFrame(data["competitions"])

competitions_df.head()
# Out:
#      id                                               area  \
# 0  2176  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 1  2166  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 2  2006  {'id': 2001, 'name': 'Africa', 'code': 'AFR', ...
# 3  2023  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
# 4  2024  {'id': 2011, 'name': 'Argentina', 'code': 'ARG...
#
#                    name  code    type  \
# 0            Africa Cup    AC     CUP
# 1  AFC Champions League   ACL     CUP
# 2  WC Qualification CAF  QCAF     CUP
# 3    Primera B Nacional   PBN  LEAGUE
# 4      Liga Profesional   ASL  LEAGUE
#
#                                       emblem       plan  \
# 0    https://crests.football-data.org/ac.png  TIER_FOUR
# 1                                        NaN  TIER_FOUR
# 2                                        NaN  TIER_FOUR
# 3                                        NaN  TIER_FOUR
# 4  https://crests.football-data.org/LPDF.svg   TIER_TWO
#
#                                        currentSeason  \
# 0  {'id': 2385, 'startDate': '2025-12-21', 'endDa...
# 1  {'id': 1559, 'startDate': '2022-04-06', 'endDa...
# 2  {'id': 1609, 'startDate': '2023-11-15', 'endDa...
# 3  {'id': 716, 'startDate': '2021-03-13', 'endDat...
# 4  {'id': 2470, 'startDate': '2026-01-22', 'endDa...
#
#    numberOfAvailableSeasons           lastUpdated
# 0                         2  2024-01-13T11:34:43Z
# 1                         1  2023-02-26T12:57:33Z
# 2                         3  2022-03-13T18:51:44Z
# 3                         5  2023-08-01T08:40:24Z
# 4                        10  2026-05-13T22:31:03Z

# %%
url_champions = "https://api.football-data.org/v4/competitions/CL/matches"

response = requests.get(url)

# %%
data = response.json()
